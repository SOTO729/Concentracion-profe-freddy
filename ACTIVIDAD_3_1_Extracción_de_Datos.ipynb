# %% [markdown]
# <a href="https://colab.research.google.com/github/SOTO729/Extracci-n-datos/blob/main/ACTIVIDAD_3_1_Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
from google.colab import files
#files.upload()

# %%
df=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df.head()
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %% [markdown]
# ***Filtro basicos para variables cualitativas***

# %%
filtro1=df[df['NOMBRE_CLIENTE']=='PÚBLICO EN GENERAL']
filtro1.head()
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  \
# 0   F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     1
# 4   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 57  F37134 2022-01-17  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     4
# 69  F37153 2022-01-20  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
#
#      CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0   TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 4    BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
# 5    BP00243    BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07
# 57   RB00010  BOB 8020 CAL.19 1612W 127V CER-8CANALES           605.00
# 69   BP00245    BAN P COMUN 100CMX21MM 900W220V T/TOR           522.00
#
#     COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# ...

# %%
filtro1=df[df['FECHA_DOC']=='2022-01-17']
filtro1.head()
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 50  F37125 2022-01-17  LETICIA RAMIREZ HERNANDEZ
# 51  F37126 2022-01-17  LETICIA RAMIREZ HERNANDEZ
# 52  F37128 2022-01-17   DIEGO ARMANDO LEON DURAN
# 53  F37129 2022-01-17   DIEGO ARMANDO LEON DURAN
# 54  F37129 2022-01-17   DIEGO ARMANDO LEON DURAN
#
#                     NOMBRE_CLIENTE  CANT           CVE_ART  \
# 50          MANUFACTURAS METALICAS     5          TUS00003
# 51                      CROPLASTIC     1  BB1 1/2X1/2-300W
# 52          DAVID LLAMAS IZQUIERDO     1            TP0008
# 53  COMPAÑIA VINICOLA SAN PATRICIO     2          TUE00324
# 54  COMPAÑIA VINICOLA SAN PATRICIO     2          TUE00325
#
#                                        DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# 50  TUB. INOX. 5/16 Øx615mm. 2000W 440V "U""            531.0           85.29
# 51           BOQUILLA 11/2X1"1/2" 300W 240V"            385.0          220.00
# ...

# %%
filtro2=df.iloc[[1,100,1000],:] #Filtro por filas
filtro2
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 100   F37223 2022-01-28  LETICIA RAMIREZ HERNANDEZ
# 1000  F39005 2022-09-07  LETICIA RAMIREZ HERNANDEZ
#
#                                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 1                         JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 100   COMPONENTES ELECTRICOS Y DISPOSITIVOS ESPECIALES     1    TP0025
# 1000                                PÚBLICO EN GENERAL     1  TUS00126
#
#                                         DESCR  PRECIO_UNITARIO  \
# 1     TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 100    TERMOPAR K 3/16Ø  X 1'  1/2 EXT. 2 MT"           175.00
# 1000      TUS INOX 5/16"ØX30CM 1000W 127V "U"           497.89
#
#       COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 1             327.18                    327.18           1264.05
# 100            75.89                     75.89            175.00
# ...

# %%
filtro2=df.iloc[:,[7,8,9,10,11,12]] #Filtro por columnas
filtro2
# Out:
#       PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0              434.48           52.80                     52.80
# 1             1264.05          327.18                    327.18
# 2              551.61          177.68                    177.68
# 3              140.00           38.96                     38.96
# 4              172.41          101.71                    101.71
# ...               ...             ...                       ...
# 1421           712.00          102.31                    102.31
# 1422           718.60          104.69                    104.69
# 1423          2182.35            0.00                    596.55
# 1424          5909.84         1884.35                   1884.35
# 1425          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO
# 0               434.48                  52.80                     381.68
# ...

# %%
filtro3=df.iloc[10:100,[7,8,9,10,11,12]] #Filtro por filas y columnas
filtro3.head()
# Out:
#     PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 10          1615.00          517.89                    517.89
# 11          1615.00            0.00                    586.32
# 12          1615.00            0.00                    586.32
# 13          1485.25            0.00                     86.22
# 14          2095.25            0.00                    742.05
#
#     SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO
# 10           1615.00                 517.89                    1097.11
# 11           1615.00                 586.32                    1028.68
# 12           1615.00                 586.32                    1028.68
# 13           1485.25                  86.22                    1399.03
# 14           2095.25                 742.05                    1353.20

# %%
df1=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx',index_col=1)
df1.head()
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#             CANT   CVE_ART                                    DESCR  \
# FECHA_DOC
# 2022-01-05     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V
# 2022-01-05     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT
# 2022-01-05     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT
# 2022-01-05     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT
# 2022-01-05     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR
#
#             PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# ...

# %%
filtro3=df1.loc[['2022-01-05','2022-01-17','2022-01-20'],['MARGEN_TOTAL_CALCULADO']] #Filtro por filas vs columnas
filtro3
# Out:
#             MARGEN_TOTAL_CALCULADO
# FECHA_DOC
# 2022-01-05                  381.68
# 2022-01-05                  936.87
# 2022-01-05                 2617.56
# 2022-01-05                  101.04
# 2022-01-05                  141.41
# 2022-01-05                  375.32
# 2022-01-05                 8676.24
# 2022-01-05                  166.62
# 2022-01-05                 1097.11
# 2022-01-05                 1097.11
# 2022-01-05                 1097.11
# 2022-01-05                 1028.68
# 2022-01-05                 1028.68
# 2022-01-05                 1399.03
# 2022-01-05                 1353.20
# 2022-01-05                   84.17
# 2022-01-05                 1294.56
# 2022-01-05                  -50.69
# 2022-01-05                 3713.02
# 2022-01-05                 5218.69
# 2022-01-05                 1406.76
# 2022-01-17                 2228.53
# 2022-01-17                  165.00
# 2022-01-17                  288.64
# 2022-01-17                 1186.05
# ...

# %%
filtro5=df.tail(90)
filtro5
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1336  F39649 2022-11-28  LETICIA RAMIREZ HERNANDEZ
# 1337  F39649 2022-11-28  LETICIA RAMIREZ HERNANDEZ
# 1338  F39654 2022-11-29             ALFREDO CANELA
# 1339  F39657 2022-11-30             ALFREDO CANELA
# 1340  F39659 2022-11-30  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1336              SABINO ALVARADO LOPEZ     1      CAE00046
# 1337              SABINO ALVARADO LOPEZ     1  CM16I2090A00
# 1338                        VALEO KAPEC     6      TUA00258
# 1339                  DWK LIFE SCIENCES     6       BO00061
# ...

# %% [markdown]
# ***Filtros basicos para variables cuantitativas***

# %%
filtro6=df[df['COSTO_TOTAL_CALCULADO']>7000]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 29    F37078 2022-01-07             ALFREDO CANELA
# 31    F37086 2022-01-10             ALFREDO CANELA
# 74    F37169 2022-01-21             ALFREDO CANELA
# 185   F37409 2022-02-18   DIEGO ARMANDO LEON DURAN
# 186   F37409 2022-02-18   DIEGO ARMANDO LEON DURAN
# 204   F37443 2022-02-23   DIEGO ARMANDO LEON DURAN
# 243   F37491 2022-02-28  LETICIA RAMIREZ HERNANDEZ
# 245   F37493 2022-02-28             ALFREDO CANELA
# 300   F37604 2022-03-10             ALFREDO CANELA
# 394   F37758 2022-03-29             ALFREDO CANELA
# 403   F37777 2022-03-31             ALFREDO CANELA
# 410   F37803 2022-03-31             ALFREDO CANELA
# 503   F37977 2022-04-25             ALFREDO CANELA
# 523   F38021 2022-04-28             ALFREDO CANELA
# 533   F38047 2022-04-29             ALFREDO CANELA
# 534   F38047 2022-04-29             ALFREDO CANELA
# 615   F38221 2022-05-24  LETICIA RAMIREZ HERNANDEZ
# ...

# %% [markdown]
# ***Filtros basicos con conectores logicos***

# %%
filtro7=df[(df['COSTO_TOTAL_CALCULADO']<6000) & (df['NOMBRE_CLIENTE']=='PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO')]#AND
filtro7
# Out:
#      CVE_DOC  FECHA_DOC NOMBRE_VENDEDOR  \
# 150   F37331 2022-02-10  ALFREDO CANELA
# 327   F37658 2022-03-16  ALFREDO CANELA
# 411   F37803 2022-03-31  ALFREDO CANELA
# 412   F37804 2022-03-31  ALFREDO CANELA
# 413   F37804 2022-03-31  ALFREDO CANELA
# 531   F38046 2022-04-29  ALFREDO CANELA
# 532   F38046 2022-04-29  ALFREDO CANELA
# 612   F38215 2022-05-23  ALFREDO CANELA
# 690   F38393 2022-06-16  ALFREDO CANELA
# 763   F38507 2022-07-04  ALFREDO CANELA
# 769   F38524 2022-07-05  ALFREDO CANELA
# 887   F38762 2022-08-08  ALFREDO CANELA
# 889   F38763 2022-08-08  ALFREDO CANELA
# 890   F38763 2022-08-08  ALFREDO CANELA
# 891   F38763 2022-08-08  ALFREDO CANELA
# 1014  F39018 2022-09-09  ALFREDO CANELA
# 1144  F39291 2022-10-12  ALFREDO CANELA
# 1252  F39500 2022-11-04  ALFREDO CANELA
# 1260  F39524 2022-11-08  ALFREDO CANELA
# 1268  F39542 2022-11-10  ALFREDO CANELA
# 1295  F39591 2022-11-16  ALFREDO CANELA
# 1386  F39774 2022-12-15  ALFREDO CANELA
# ...

# %%
filtro8=df[(df['CANT']<10) | (df['NOMBRE_VENDEDOR']=='ALFREDO CANELA')]#OR
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
filtro9=df[~(df['PRECIO_UNITARIO']<600) &~ (df['NOMBRE_CLIENTE']=='ANA BARBARA CRUZ PALACIOS')]#NOT
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10    F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# 8                      FIDEICOMISO F/1596     1      TUE00207
# 9                      FIDEICOMISO F/1596     1      TUE00207
# ...

# %%
filtro9.to_csv('Entregable1.csv')

# %%
from google.colab import files
files.download('Entregable1.csv')
